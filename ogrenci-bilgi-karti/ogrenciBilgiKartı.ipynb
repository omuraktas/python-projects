# %%
# Öğrenci Bilgi Kartı Projesi


#Dersler 
alinanDersler = ["Java", "C", "Python"]
alinanDersler.sort()

#Öğrenciden Alınacak Veriler
ogrenciAdi = input("Lütfen adınızı giriniz:")
ogrenciSoyadi = input("Lütfen soyadınızı giriniz:")
ogrenciYasi = input("Lütfen yaşınızı giriniz:")
ogrenciBoy = input("Lütfen boyunuzu giriniz:")
ogrenciMezun = input("Mezun musunuz?\nTrue OR False :")
ogrenciStaj = input("Staj yaptınız mı? \nTrue OR False :")
ogrenciVize = input("Lütfen Vize notunuzu giriniz:")
ogrenciFinal = input("Lütfen Final notunuzu giriniz:")
ogrenciProje = input("Lütfen proje notunuzu giriniz:")∏
print("----Aldığınız Dersler----")
print(alinanDersler)
ogrenciDers = input("Lütfen bırakmak istediğniz ve almak istediğniz\ndersi arasında virgül koyarak giriniz(boşluk bırakmayınız): ")
ogrenciEtkinlik = input("Lütfen katıldığnız tüm etkinlikleri arasında virgül koyarak giriniz: ")

#Öğrenci Adı ve Soyadı Düzenleme
ogrenciKucukAdi = ogrenciAdi.lower()
ogrenciKucukSoyadi = ogrenciSoyadi.lower()
ogrenciAdiDuzenli = ogrenciKucukAdi.capitalize()
ogrenciSoyadiDuzenli = ogrenciKucukSoyadi.capitalize()
ogrenciTamAdi = ogrenciAdiDuzenli + " " + ogrenciSoyadiDuzenli

# String değerleri int'e cevirme ve ortalama hesaplama
ogrenciYasi = int(ogrenciYasi)
ogrenciBoy = int(ogrenciBoy)


ogrenciVize = int(ogrenciVize)
ogrenciFinal = int(ogrenciFinal)
ogrenciProje = int(ogrenciProje)

ogrenciNotlar = [ogrenciVize,ogrenciFinal,ogrenciProje]

ogrenciNotToplami = sum(ogrenciNotlar)
ogrenciNotOrtalaması = ogrenciNotToplami/3
ogrenciNotMax = max(ogrenciNotlar)
ogrenciNotMin = min(ogrenciNotlar)


#Ders cıkarma ve ekleme
dersDuzenle = ogrenciDers.split(",")

silinecek_ders = dersDuzenle[0].strip().capitalize()
eklenecek_ders = dersDuzenle[1].strip().capitalize()

alinanDersler.remove(silinecek_ders)
alinanDersler.append(eklenecek_ders)

#Öğrenci Bilgilerini Sözlükte tutma
ogrenciBilgileri = {"adıSoyadı" : ogrenciTamAdi,
                    "yasi" : ogrenciYasi, 
                    "boyu" : ogrenciBoy, 
                   }

ogrenciBilgileri["ortalama"]= ogrenciNotOrtalaması
ogrenciBilgileri["notMax"]= ogrenciNotMax
ogrenciBilgileri["notMin"]= ogrenciNotMin

aktifOgrenci=True
ogrenciBilgileri["aktifOgrenciMi"]= aktifOgrenci
ogrenciBilgileri["staj"]= ogrenciStaj
ogrenciBilgileri["mezunMu"]= ogrenciMezun

#Etkinlik ve Değişmemesi gereken okul bilgileri
ogrenciDuzenliEtkinlik = ogrenciEtkinlik.split(",")
ogrenciBenzersizEtkinlikerli = set(ogrenciDuzenliEtkinlik)

okulBilgileri = ("İstanbul Aydın Üniversitesi","Mühendislik Fakültesi","Bilgisayar Mühendisliği")

#Ogrenci Bilgi Menüsü
print("\n\n\n-----------Öğrenci Bilgileri-----------")
print("Öğrencinin Adı ve Soyadı: "  + ogrenciBilgileri["adıSoyadı"])
print("Öğrencinin Yaşı: "  , ogrenciBilgileri["yasi"])
print("Öğrencinin Boyu: "  , ogrenciBilgileri["boyu"] ," cm")
print("Öğrencinin Ortalaması: "  , ogrenciBilgileri["ortalama"])
print("Öğrencinin En Yüksek Notu: "  , ogrenciBilgileri["notMax"])
print("Öğrencinin En Düşük Notu: "  , ogrenciBilgileri["notMin"])
print("Öğrencinin Aktif Mi: "  , ogrenciBilgileri["aktifOgrenciMi"])
print("Öğrencinin Mezun Mu: "  + ogrenciBilgileri["mezunMu"])
print("Öğrencinin Staj: "  + ogrenciBilgileri["staj"])
print("Öğrencinin Okulu: "  + okulBilgileri[0])
print("Öğrencinin Fakültesi: "  + okulBilgileri[1])
print("Öğrencinin Bölümü: "  + okulBilgileri[2])
print("\n\n----Aldığı Dersler----")
print(alinanDersler)
print("\n\n----Katıldığı Etkinlikler----")
print(ogrenciBenzersizEtkinlikerli)
print("-------------------------------------------------")
# Out:
# Lütfen adınızı giriniz: ömür
# Lütfen soyadınızı giriniz: aktaş
# Lütfen yaşınızı giriniz: 22
# Lütfen boyunuzu giriniz: 188
# Mezun musunuz?
# True OR False : false
# Staj yaptınız mı?
# True OR False : true
# Lütfen Vize notunuzu giriniz: 12
# Lütfen Final notunuzu giriniz: 45
# Lütfen proje notunuzu giriniz: 89
# ----Aldığınız Dersler----
# ['C', 'Java', 'Python']
# Lütfen bırakmak istediğniz ve almak istediğniz
# dersi arasında virgül koyarak giriniz(boşluk bırakmayınız):  c,bilgisayar
# Lütfen katıldığnız tüm etkinlikleri arasında virgül koyarak giriniz:  Programlama,c,java
# -----------Öğrenci Bilgileri-----------
# Öğrencinin Adı ve Soyadı: Ömür Aktaş
# Öğrencinin Yaşı:  22
# Öğrencinin Boyu:  188  cm
# Öğrencinin Ortalaması:  48.666666666666664
# Öğrencinin Aktif Mi:  True
# Öğrencinin Mezun Mu: false
# Öğrencinin Staj: true
# Öğrencinin Okulu: İstanbul Aydın Üniversitesi
# Öğrencinin Fakültesi: Mühendislik Fakültesi
# Öğrencinin Bölümü: Bilgisayar Mühendisliği
#
#
# ...
